# %% [markdown]
# <a href="https://colab.research.google.com/github/umair-gmrm/AI-Foundation-Batch-3/blob/main/Initial_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Word!")
# Out:
# Hello! Word!
